# %%
os.listdir('/home/jack/Desktop/ChatterBot-Stuff/NEW/test/')
# Out:
# ['Cbwsjson.json',
#  'brejson.json',
#  'Cbqsjson.json',
#  'Cbvljson.json',
#  'bgcjson.json',
#  'btrjson.json',
#  'byxjson.json',
#  'birjson.json',
#  'bgujson.json',
#  'Cbdvjson.json',
#  'Cbbqjson.json',
#  'byujson.json',
#  'beyjson.json',
#  'Cbaejson.json',
#  'bejjson.json',
#  'Cbcejson.json',
#  'Cbpyjson.json',
#  'bizjson.json',
#  'bdcjson.json',
#  'Cbtrjson.json',
#  'Cbgyjson.json',
#  'Cbgxjson.json',
#  'bgyjson.json',
#  'bucjson.json',
#  'bzrjson.json',
#  'Cbcajson.json',
#  'bpljson.json',
#  'Cbwvjson.json',
#  'bwfjson.json',
#  'bhzjson.json',
#  'Cbkzjson.json',
#  'bjxjson.json',
#  'Cbdejson.json',
#  'Cbaljson.json',
#  'Cbfljson.json',
#  'bhojson.json',
#  'bxrjson.json',
#  'Cbgsjson.json',
#  'Cbnfjson.json',
#  'bwxjson.json',
#  'bvhjson.json',
#  'bwgjson.json',
#  'Cbtvjson.json',
#  'Cbubjson.json',
#  'bnhjson.json',
#  'bvgjson.json',
#  'bvyjson.json',
#  'bisjson.json',
#  'bwrjson.json',
#  'Cbqvjson.json',
#  'Cboojson.json',
#  'bdujson.json',
#  'Cbtsjson.json',
#  'Cbbajson.json',
#  'bsbjson.json',
#  'btljson.json',
#  'byajson.json',
#  'borjson.json',
#  'bdzjson.json',
#  'bnejson.json',
#  'bsfjson.json',
#  'bsljson.json',
#  'Cbnvjson.json',
#  'Cbygjson.json',
#  'bgnjson.json',
#  'bvnjson.json',
#  'bxsjson.json',
#  'bdnjson.json',
#  'bjyjson.json',
#  'bigjson.json',
#  'bfrjson.json',
#  'Cbxsjson.json',
#  'bnkjson.json',
#  'Cbbdjson.json',
#  'Cbjejson.json',
#  'benjson.json',
#  'bojjson.json',
#  'Cbopjson.json',
#  'Cbqrjson.json',
#  'Cbiijson.json',
#  'bpnjson.json',
#  'Cbfujson.json',
#  'Cbwcjson.json',
#  'Cbbvjson.json',
#  'Cbhnjson.json',
#  'Cbtljson.json',
#  'Cbhsjson.json',
#  'bkdjson.json',
#  'Cbnsjson.json',
#  'bvdjson.json',
#  'bakjson.json',
#  'Cbsqjson.json',
#  'Cbibjson.json',
#  'Cbufjson.json',
#  'Cbfwjson.json',
#  'Cbbujson.json',
#  'Cbfvjson.json',
#  'buzjson.json',
#  'Cbtqjson.json',
#  'Cbxbjson.json',
#  'bqfjson.json',
#  'brqjson.json',
#  'Cbnbjson.json',
#  'Cbsfjson.json',
#  'Cbdojson.json',
#  'bpujson.json',
#  'Cbcljson.json',
#  'bjajson.json',
#  'bnujson.json',
#  'Cbhijson.json',
#  'Cbuijson.json',
#  'bzujson.json',
#  'Cbzjjson.json',
#  'Cbiajson.json',
#  'Cbuojson.json',
#  'Cbyjjson.json',
#  'brdjson.json',
#  'Cbudjson.json',
#  'brvjson.json',
#  'bghjson.json',
#  'Cbgwjson.json',
#  'bwajson.json',
#  'Cbqgjson.json',
#  'Cbiyjson.json',
#  'bfsjson.json',
#  'Cbrljson.json',
#  'Cbssjson.json',
#  'Cbnujson.json',
#  'Cbdzjson.json',
#  'bxzjson.json',
#  'bsujson.json',
#  'Cbiejson.json',
#  'Cboljson.json',
#  'Cbasjson.json',
#  'bfajson.json',
#  'busjson.json',
#  'bopjson.json',
#  'Cbzxjson.json',
#  'Cbnejson.json',
#  'blljson.json',
#  'bcxjson.json',
#  'Cbiwjson.json',
#  'Cbffjson.json',
#  'bxnjson.json',
#  'Cbzijson.json',
#  'Cbyrjson.json',
#  'Cbsxjson.json',
#  'banjson.json',
#  'Cboyjson.json',
#  'Cbxtjson.json',
#  'Cbyljson.json',
#  'Cbeljson.json',
#  'Cbkejson.json',
#  'btpjson.json',
#  'Cbsbjson.json',
#  'Cbjijson.json',
#  'Cbenjson.json',
#  'bagjson.json',
#  'bxtjson.json',
#  'bidjson.json',
#  'Cbljjson.json',
#  'bhfjson.json',
#  'Cbgpjson.json',
#  'bjgjson.json',
#  'brfjson.json',
#  'Cbxzjson.json',
#  'bfcjson.json',
#  'bwljson.json',
#  'Cbawjson.json',
#  'bufjson.json',
#  'Cbfpjson.json',
#  'btjjson.json',
#  'bdfjson.json',
#  'bkejson.json',
#  'Cbtyjson.json',
#  'Cblqjson.json',
#  'bbbjson.json',
#  'bjijson.json',
#  'Cbpbjson.json',
#  'Cbbtjson.json',
#  'bazjson.json',
#  'bobjson.json',
#  'bqxjson.json',
#  'Cbrhjson.json',
#  'bntjson.json',
#  'bcbjson.json',
#  'bsojson.json',
#  'bsqjson.json',
#  'bqsjson.json',
#  'bzgjson.json',
#  'Cbuwjson.json',
#  'bjojson.json',
#  'btdjson.json',
#  'bczjson.json',
#  'bawjson.json',
#  'bdajson.json',
#  'Cbvujson.json',
#  'bqujson.json',
#  'Cbjqjson.json',
#  'Cbwxjson.json',
#  'bbgjson.json',
#  'Cbgujson.json',
#  'bsdjson.json',
#  'bqrjson.json',
#  'Cbpijson.json',
#  'Cbzujson.json',
#  'bqojson.json',
#  'Cbykjson.json',
#  'brkjson.json',
#  'Cblbjson.json',
#  'Cbgajson.json',
#  'bgwjson.json',
#  'Cbzhjson.json',
#  'bchjson.json',
#  'blrjson.json',
#  'bewjson.json',
#  'bkojson.json',
#  'bsxjson.json',
#  'Cbwbjson.json',
#  'Cbirjson.json',
#  'bzqjson.json',
#  'Cbbbjson.json',
#  'bexjson.json',
#  'bgtjson.json',
#  'brujson.json',
#  'Cbtijson.json',
#  'bzxjson.json',
#  'Cbjzjson.json',
#  'bhkjson.json',
#  'bdhjson.json',
#  'bdrjson.json',
#  'Cbzljson.json',
#  'Cbeijson.json',
#  'Cbkwjson.json',
#  'bjpjson.json',
#  'Cbxjjson.json',
#  'Cbrqjson.json',
#  'bunjson.json',
#  'Cboujson.json',
#  'Cbeyjson.json',
#  'Cbbfjson.json',
#  'btejson.json',
#  'bxijson.json',
#  'Cbsgjson.json',
#  'bnljson.json',
#  'Cbcsjson.json',
#  'bhsjson.json',
#  'bcfjson.json',
#  'Cbuljson.json',
#  'bcojson.json',
#  'bnbjson.json',
#  'Cbxhjson.json',
#  'blnjson.json',
#  'Cbdcjson.json',
#  'bpejson.json',
#  'bddjson.json',
#  'bvrjson.json',
#  'Cbpxjson.json',
#  'bjvjson.json',
#  'Cbevjson.json',
#  'bhcjson.json',
#  'Cbotjson.json',
#  'Cblljson.json',
#  'Cbkpjson.json',
#  'buvjson.json',
#  'Cbgtjson.json',
#  'bxhjson.json',
#  'bnyjson.json',
#  'Cbexjson.json',
#  'bhgjson.json',
#  'bhvjson.json',
#  'Cbovjson.json',
#  'Cbyujson.json',
#  'Cbrvjson.json',
#  'bpyjson.json',
#  'Cbqpjson.json',
#  'Cbskjson.json',
#  'Cbsdjson.json',
#  'bqajson.json',
#  'bfljson.json',
#  'blqjson.json',
#  'bdkjson.json',
#  'bihjson.json',
#  'Cbrbjson.json',
#  'Cbeojson.json',
#  'Cbodjson.json',
#  'bltjson.json',
#  'Cbaajson.json',
#  'Cbbejson.json',
#  'brsjson.json',
#  'Cbhujson.json',
#  'biljson.json',
#  'bcijson.json',
#  'Cbrnjson.json',
#  'bysjson.json',
#  'bjljson.json',
#  'Cbhgjson.json',
#  'bafjson.json',
#  'bvijson.json',
#  'Cbaojson.json',
#  'Cbswjson.json',
#  'bjcjson.json',
#  'bpdjson.json',
#  'Cbqkjson.json',
#  'Cbsijson.json',
#  'Cbfgjson.json',
#  'Cbagjson.json',
#  'bcwjson.json',
#  'Cbujjson.json',
#  'biyjson.json',
#  'badjson.json',
#  'bxujson.json',
#  'Cbkrjson.json',
#  'Cbhojson.json',
#  'Cbjjjson.json',
#  'Cbpcjson.json',
#  'Cbeqjson.json',
#  'Cbpfjson.json',
#  'baljson.json',
#  'Cbocjson.json',
#  'bggjson.json',
#  'Cbzpjson.json',
#  'boijson.json',
#  'Cbcqjson.json',
#  'Cbkbjson.json',
#  'Cbxfjson.json',
#  'Cbsjjson.json',
#  'Cbewjson.json',
#  'Cbuhjson.json',
#  'bgqjson.json',
#  'bbajson.json',
#  'bqbjson.json',
#  'Cbcfjson.json',
#  'bpbjson.json',
#  'Cbigjson.json',
#  'bixjson.json',
#  'Cbsujson.json',
#  'Cbanjson.json',
#  'Cbgijson.json',
#  'Cbgejson.json',
#  'Cbczjson.json',
#  'byljson.json',
#  'bqcjson.json',
#  'bynjson.json',
#  'boqjson.json',
#  'Cbukjson.json',
#  'Cbebjson.json',
#  'bpxjson.json',
#  'Cbwrjson.json',
#  'bxljson.json',
#  'Cbhwjson.json',
#  'Cbzyjson.json',
#  'Cbprjson.json',
#  'bscjson.json',
#  'Cbojjson.json',
#  'bgejson.json',
#  'Cbvvjson.json',
#  'Cbtajson.json',
#  'bbjjson.json',
#  'Cbyvjson.json',
#  'Cbacjson.json',
#  'Cbjsjson.json',
#  'bfbjson.json',
#  'Cbxxjson.json',
#  'brwjson.json',
#  'Cbnjjson.json',
#  'bxdjson.json',
#  'bxyjson.json',
#  'bcsjson.json',
#  'Cbdwjson.json',
#  'Cbeujson.json',
#  'blyjson.json',
#  'bpcjson.json',
#  'Cbfkjson.json',
#  'bvujson.json',
#  'bfhjson.json',
#  'blgjson.json',
#  'Cboqjson.json',
#  'bcpjson.json',
#  'Cbbkjson.json',
#  'Cbkujson.json',
#  'bzijson.json',
#  'Cboejson.json',
#  'Cbcujson.json',
#  'beajson.json',
#  'bgjjson.json',
#  'Cbysjson.json',
#  'bbljson.json',
#  'boyjson.json',
#  'bqijson.json',
#  'Cbihjson.json',
#  'bgdjson.json',
#  'bwvjson.json',
#  'Cbppjson.json',
#  'Cbqhjson.json',
#  'bgfjson.json',
#  'Cbayjson.json',
#  'btkjson.json',
#  'bwwjson.json',
#  'Cbvtjson.json',
#  'Cbjnjson.json',
#  'Cbtnjson.json',
#  'Cbiqjson.json',
#  'bzyjson.json',
#  'Cbvxjson.json',
#  'Cbckjson.json',
#  'Cbqxjson.json',
#  'Cbuyjson.json',
#  'bbijson.json',
#  'Cbcijson.json',
#  'Cbgljson.json',
#  'bspjson.json',
#  'Cbypjson.json',
#  'bnqjson.json',
#  'Cbhvjson.json',
#  'bfpjson.json',
#  'Cbwjjson.json',
#  'bktjson.json',
#  'Cbtpjson.json',
#  'Cbdujson.json',
#  'bvpjson.json',
#  'Cblojson.json',
#  'buujson.json',
#  'Cbdbjson.json',
#  'Cbydjson.json',
#  'Cbspjson.json',
#  'Cbqujson.json',
#  'Cbbljson.json',
#  'brcjson.json',
#  'Cbwhjson.json',
#  'Cbtgjson.json',
#  'Cbzqjson.json',
#  'Cbwfjson.json',
#  'btvjson.json',
#  'bhejson.json',
#  'bwejson.json',
#  'Cbzajson.json',
#  'biujson.json',
#  'Cbrojson.json',
#  'bbejson.json',
#  'bcujson.json',
#  'bycjson.json',
#  'bccjson.json',
#  'Cbdijson.json',
#  'Cbbnjson.json',
#  'Cbvejson.json',
#  'blkjson.json',
#  'bdjjson.json',
#  'Cbzkjson.json',
#  'byyjson.json',
#  'bjhjson.json',
#  'Cblejson.json',
#  'Cbvpjson.json',
#  'bhjjson.json',
#  'bdsjson.json',
#  'bzpjson.json',
#  'bhqjson.json',
#  'Cbqqjson.json',
#  'Cbwpjson.json',
#  'Cbzcjson.json',
#  'bdbjson.json',
#  'bbkjson.json',
#  'bwtjson.json',
#  'Cbbsjson.json',
#  'Cbxojson.json',
#  'bqkjson.json',
#  'Cbwejson.json',
#  'Cbcbjson.json',
#  'bnojson.json',
#  'bonjson.json',
#  'bgrjson.json',
#  'bwzjson.json',
#  'bppjson.json',
#  'blajson.json',
#  'bsijson.json',
#  'bvxjson.json',
#  'Cbjvjson.json',
#  'Cbehjson.json',
#  'bldjson.json',
#  'Cborjson.json',
#  'bupjson.json',
#  'Cbgfjson.json',
#  'Cbwijson.json',
#  'bhljson.json',
#  'biajson.json',
#  'Cbaijson.json',
#  'bdwjson.json',
#  'Cbnyjson.json',
#  'blojson.json',
#  'Cbuejson.json',
#  'bsvjson.json',
#  'bszjson.json',
#  'Cbcvjson.json',
#  'bkkjson.json',
#  'bicjson.json',
#  'biqjson.json',
#  'Cbbijson.json',
#  'blujson.json',
#  'bdpjson.json',
#  'bqpjson.json',
#  'buqjson.json',
#  'bhrjson.json',
#  'bipjson.json',
#  'Cbsojson.json',
#  'Cbthjson.json',
#  'btbjson.json',
#  'bajjson.json',
#  'bhwjson.json',
#  'Cbynjson.json',
#  'bprjson.json',
#  'Cbtwjson.json',
#  'bdqjson.json',
#  'bftjson.json',
#  'Cbpnjson.json',
#  'Cbaujson.json',
#  'bsrjson.json',
#  'Cbnwjson.json',
#  'bkajson.json',
#  'blvjson.json',
#  'Cbfnjson.json',
#  'Cbgojson.json',
#  'bodjson.json',
#  'Cbkkjson.json',
#  'brjjson.json',
#  'Cbdrjson.json',
#  'Cbzojson.json',
#  'Cbbyjson.json',
#  'Cbafjson.json',
#  'Cbahjson.json',
#  'Cbdfjson.json',
#  'Cbnqjson.json',
#  'Cbfijson.json',
#  'Cbtxjson.json',
#  'bcnjson.json',
#  'beqjson.json',
#  'Cbiujson.json',
#  'bznjson.json',
#  'Cbfojson.json',
#  'bkijson.json',
#  'bsajson.json',
#  'Cbabjson.json',
#  'Cbrejson.json',
#  'blfjson.json',
#  'Cbrwjson.json',
#  'bavjson.json',
#  'bnpjson.json',
#  'Cbkyjson.json',
#  'bwbjson.json',
#  'bezjson.json',
#  'buljson.json',
#  'Cbatjson.json',
#  'Cbtjjson.json',
#  'bkjjson.json',
#  'bncjson.json',
#  'bfijson.json',
#  'bydjson.json',
#  'Cbngjson.json',
#  'Cbokjson.json',
#  'bzhjson.json',
#  'Cbjkjson.json',
#  'Cbsyjson.json',
#  'Cbqajson.json',
#  'bdvjson.json',
#  'Cbyxjson.json',
#  'Cbuvjson.json',
#  'Cbpjjson.json',
#  'Cbqejson.json',
#  'bqnjson.json',
#  'bsnjson.json',
#  'Cbekjson.json',
#  'Cbfjjson.json',
#  'Cbqwjson.json',
#  'Cbzzjson.json',
#  'bkhjson.json',
#  'bjqjson.json',
#  'bnvjson.json',
#  'Cbunjson.json',
#  'bbfjson.json',
#  'bqtjson.json',
#  'bzojson.json',
#  'Cblxjson.json',
#  'bcgjson.json',
#  'bndjson.json',
#  'bnnjson.json',
#  'Cbhjjson.json',
#  'bekjson.json',
#  'Cbtkjson.json',
#  'bshjson.json',
#  'bssjson.json',
#  'bckjson.json',
#  'bkwjson.json',
#  'bbojson.json',
#  'Cbobjson.json',
#  'Cbnajson.json',
#  'bijjson.json',
#  'Cblyjson.json',
#  'Cbdgjson.json',
#  'bdojson.json',
#  'Cbvnjson.json',
#  'bsejson.json',
#  'Cbyejson.json',
#  'Cbhljson.json',
#  'bhajson.json',
#  'Cbwdjson.json',
#  'bwsjson.json',
#  'Cbqijson.json',
#  'bfxjson.json',
#  'bfnjson.json',
#  'Cbeajson.json',
#  'Cbzdjson.json',
#  'Cbxajson.json',
#  'bztjson.json',
#  'bzzjson.json',
#  'bkzjson.json',
#  'basjson.json',
#  'bbtjson.json',
#  'bbcjson.json',
#  'Cbggjson.json',
#  'brnjson.json',
#  'byrjson.json',
#  'blhjson.json',
#  'bikjson.json',
#  'bgsjson.json',
#  'btojson.json',
#  'bybjson.json',
#  'Cbqzjson.json',
#  'bwkjson.json',
#  'bjsjson.json',
#  'Cbnhjson.json',
#  'Cbbojson.json',
#  'Cbiljson.json',
#  'Cbfcjson.json',
#  'bpajson.json',
#  'bbyjson.json',
#  'Cbjhjson.json',
#  'Cbfsjson.json',
#  'bowjson.json',
#  'Cbndjson.json',
#  'Cbztjson.json',
#  'bjtjson.json',
#  'bskjson.json',
#  'Cbttjson.json',
#  'Cbpkjson.json',
#  'Cbusjson.json',
#  'Cbpwjson.json',
#  'Cbzbjson.json',
#  'butjson.json',
#  'bgajson.json',
#  'bkbjson.json',
#  'Cbwojson.json',
#  'Cbugjson.json',
#  'bsjjson.json',
#  'bkvjson.json',
#  'Cbupjson.json',
#  'Cblrjson.json',
#  'bcqjson.json',
#  'Cbvyjson.json',
#  'bkljson.json',
#  'Cbqojson.json',
#  'Cbkjjson.json',
#  'byvjson.json',
#  'Cbkxjson.json',
#  'bfojson.json',
#  'Cblvjson.json',
#  'baajson.json',
#  'bvbjson.json',
#  'burjson.json',
#  'Cbdxjson.json',
#  'bukjson.json',
#  'Cbvdjson.json',
#  'bkgjson.json',
#  'Cbjpjson.json',
#  'Cbapjson.json',
#  'byjjson.json',
#  'btgjson.json',
#  'Cbxcjson.json',
#  'Cboajson.json',
#  'Cbxyjson.json',
#  'bxxjson.json',
#  'biwjson.json',
#  'bacjson.json',
#  'bxbjson.json',
#  'bhijson.json',
#  'Cbycjson.json',
#  'Cbwkjson.json',
#  'bqejson.json',
#  'bpsjson.json',
#  'baxjson.json',
#  'Cbqjjson.json',
#  'Cbpujson.json',
#  'Cbdnjson.json',
#  'bubjson.json',
#  'Cbhajson.json',
#  'Cbphjson.json',
#  'baqjson.json',
#  'brxjson.json',
#  'Cbdhjson.json',
#  'byqjson.json',
#  'bksjson.json',
#  'brajson.json',
#  'bnzjson.json',
#  'bqgjson.json',
#  'bjdjson.json',
#  'bvwjson.json',
#  'bknjson.json',
#  'bkrjson.json',
#  'btxjson.json',
#  'bpzjson.json',
#  'bhhjson.json',
#  'Cbpvjson.json',
#  'bljjson.json',
#  'beijson.json',
#  'Cbcrjson.json',
#  'Cbyhjson.json',
#  'Cblwjson.json',
#  'blxjson.json',
#  'bnajson.json',
#  'boujson.json',
#  'Cbrgjson.json',
#  'bibjson.json',
#  'Cbpojson.json',
#  'Cbptjson.json',
#  'bbsjson.json',
#  'bdxjson.json',
#  'Cbdajson.json',
#  'Cbnljson.json',
#  'batjson.json',
#  'Cbsnjson.json',
#  'bvsjson.json',
#  'Cbuajson.json',
#  'bttjson.json',
#  'bhujson.json',
#  'Cbfbjson.json',
#  'Cbjrjson.json',
#  'Cbbgjson.json',
#  'bzwjson.json',
#  'bzcjson.json',
#  'Cbsvjson.json',
#  'Cbzsjson.json',
#  'bzjjson.json',
#  'bhdjson.json',
#  'Cblnjson.json',
#  'bfejson.json',
#  'Cbrjjson.json',
#  'Cbyajson.json',
#  'bevjson.json',
#  'buwjson.json',
#  'Cbqfjson.json',
#  'bovjson.json',
#  'biojson.json',
#  'bgbjson.json',
#  'blbjson.json',
#  'Cbyfjson.json',
#  'bhyjson.json',
#  'Cbbcjson.json',
#  'Cbvojson.json',
#  'Cbfzjson.json',
#  'bzejson.json',
#  'bvejson.json',
#  'Cbnnjson.json',
#  'Cbqbjson.json',
#  'Cblpjson.json',
#  'btcjson.json',
#  'bygjson.json',
#  'bqwjson.json',
#  'Cbccjson.json',
#  'Cbknjson.json',
#  'Cbchjson.json',
#  'Cbgcjson.json',
#  'Cbvgjson.json',
#  'Cbrpjson.json',
#  'bwojson.json',
#  'bkujson.json',
#  'Cbetjson.json',
#  'bvqjson.json',
#  'becjson.json',
#  'bjejson.json',
#  'bgljson.json',
#  'barjson.json',
#  'bwhjson.json',
#  'Cbctjson.json',
#  'Cbjcjson.json',
#  'btijson.json',
#  'Cbuxjson.json',
#  'buojson.json',
#  'byijson.json',
#  'Cbpdjson.json',
#  'bdejson.json',
#  'bxajson.json',
#  'Cbofjson.json',
#  'Cbpqjson.json',
#  'bedjson.json',
#  'boejson.json',
#  'Cbnpjson.json',
#  'Cblzjson.json',
#  'Cbgrjson.json',
#  'bozjson.json',
#  'Cbhhjson.json',
#  'Cbxdjson.json',
#  'boljson.json',
#  'Cbutjson.json',
#  'bgojson.json',
#  'botjson.json',
#  'byojson.json',
#  'Cbuujson.json',
#  'bzsjson.json',
#  'Cburjson.json',
#  'Cbhpjson.json',
#  'btqjson.json',
#  'bqyjson.json',
#  'buxjson.json',
#  'Cbnzjson.json',
#  'Cbdjjson.json',
#  'Cbzrjson.json',
#  'Cbghjson.json',
#  'Cblujson.json',
#  'buajson.json',
#  'bjrjson.json',
#  'Cbtojson.json',
#  'bpjjson.json',
#  'Cbazjson.json',
#  'bbujson.json',
#  'bvcjson.json',
#  'Cbsajson.json',
#  'Cbjojson.json',
#  'Cbeejson.json',
#  'Cbvbjson.json',
#  'bwdjson.json',
#  'bohjson.json',
#  'Cbqljson.json',
#  'bitjson.json',
#  'Cbwwjson.json',
#  'biijson.json',
#  'Cbikjson.json',
#  'Cbkfjson.json',
#  'Cbwnjson.json',
#  'Cbhtjson.json',
#  'Cbucjson.json',
#  'Cbtejson.json',
#  'Cbepjson.json',
#  'Cbwzjson.json',
#  'bsgjson.json',
#  'Cbktjson.json',
#  'bdyjson.json',
#  'bhpjson.json',
#  'buhjson.json',
#  'Cbhzjson.json',
#  'Cbcpjson.json',
#  'Cbdtjson.json',
#  'bbxjson.json',
#  'blwjson.json',
#  'Cbtfjson.json',
#  'Cbfrjson.json',
#  'bbpjson.json',
#  'bxgjson.json',
#  'beojson.json',
#  'Cbisjson.json',
#  'bocjson.json',
#  'bxjjson.json',
#  'bwujson.json',
#  'bqdjson.json',
#  'bayjson.json',
#  'bosjson.json',
#  'bqqjson.json',
#  'bctjson.json',
#  'Cbnojson.json',
#  'Cbsljson.json',
#  'Cbfhjson.json',
#  'Cbvzjson.json',
#  'Cbvjjson.json',
#  'Cbxrjson.json',
#  'Cbtzjson.json',
#  'Cbxpjson.json',
#  'Cbakjson.json',
#  'bkcjson.json',
#  'bxqjson.json',
#  'Cbipjson.json',
#  'Cboijson.json',
#  'Cbdyjson.json',
#  'Cbzwjson.json',
#  'bkqjson.json',
#  'bbqjson.json',
#  'btnjson.json',
#  'btajson.json',
#  'Cbfdjson.json',
#  'Cbhdjson.json',
#  'buyjson.json',
#  'bjbjson.json',
#  'Cbkhjson.json',
#  'bcajson.json',
#  'brhjson.json',
#  'betjson.json',
#  'bcjjson.json',
#  'bfyjson.json',
#  'Cbnrjson.json',
#  'bxpjson.json',
#  'bifjson.json',
#  'bffjson.json',
#  'Cbcwjson.json',
#  'bqljson.json',
#  'Cbfqjson.json',
#  'bbzjson.json',
#  'bjujson.json',
#  'Cbkdjson.json',
#  'Cbgzjson.json',
#  'bthjson.json',
#  'Cbgdjson.json',
#  'bjjjson.json',
#  'buejson.json',
#  'Cbbxjson.json',
#  'Cbajjson.json',
#  'bngjson.json',
#  'Cbkijson.json',
#  'Cbtdjson.json',
#  'Cbksjson.json',
#  'Cblkjson.json',
#  'bdljson.json',
#  'Cbkgjson.json',
#  'bqjjson.json',
#  'Cbbpjson.json',
#  'Cblhjson.json',
#  'bqvjson.json',
#  'Cbntjson.json',
#  'Cboxjson.json',
#  'beujson.json',
#  'blzjson.json',
#  'bcyjson.json',
#  'Cbyojson.json',
#  'Cbsejson.json',
#  'Cbxwjson.json',
#  'Cbwgjson.json',
#  'Cbyyjson.json',
#  'Cbwyjson.json',
#  'Cbvkjson.json',
#  'Cbhkjson.json',
#  'bivjson.json',
#  'Cbvhjson.json',
#  'Cbtujson.json',
#  'Cbqnjson.json',
#  'bxejson.json',
#  'Cbpzjson.json',
#  'Cbkvjson.json',
#  'bofjson.json',
#  'Cbejjson.json',
#  'bvzjson.json',
#  'bkfjson.json',
#  'Cbxejson.json',
#  'byhjson.json',
#  'Cbyijson.json',
#  'Cbwajson.json',
#  'Cbvwjson.json',
#  'bvkjson.json',
#  'Cbbhjson.json',
#  'bgxjson.json',
#  'Cbhqjson.json',
#  'Cbshjson.json',
#  'bfujson.json',
#  'bepjson.json',
#  'Cberjson.json',
#  'Cbvqjson.json',
#  'bujjson.json',
#  'bcvjson.json',
#  'Cbdljson.json',
#  'Cbnijson.json',
#  'btfjson.json',
#  'bzdjson.json',
#  'Cbrajson.json',
#  'berjson.json',
#  'Cbpgjson.json',
#  'Cbvfjson.json',
#  'Cblsjson.json',
#  'Cbnxjson.json',
#  'bypjson.json',
#  'Cbosjson.json',
#  'Cbavjson.json',
#  'bhtjson.json',
#  'Cblgjson.json',
#  'brojson.json',
#  'bzbjson.json',
#  'Cbegjson.json',
#  'bryjson.json',
#  'bxwjson.json',
#  'Cbjfjson.json',
#  'Cbddjson.json',
#  'Cbzgjson.json',
#  'Cbryjson.json',
#  'bpkjson.json',
#  'bcdjson.json',
#  'bzljson.json',
#  'Cbqdjson.json',
#  'bvfjson.json',
#  'blijson.json',
#  'Cbrfjson.json',
#  'bfkjson.json',
#  'Cbytjson.json',
#  'bwcjson.json',
#  'baejson.json',
#  'bkyjson.json',
#  'Cbgkjson.json',
#  'bqzjson.json',
#  ...]

# %%
# !ls /home/jack/Desktop/ChatterBot-Stuff/test

# %%
invalid_json_files = []
read_json_files = []
import simplejson
import json
def parse(PATH):
    #for files in os.listdir("/home/jack/Desktop/ChatterBot-Stuff/NEW/test/"):
    for files in os.listdir(PATH):
        print(PATH+files) 
        if "C" in files:
            with open(PATH+files) as json_file:
            
                try:
                    simplejson.load(json_file)
                    read_json_files.append(files)
                except ValueError as e:
                    print ("JSON object issue: ", e)
                    invalid_json_files.append(files)
        print (invalid_json_files, len(read_json_files))
PATH="/home/jack/Desktop/ChatterBot-Stuff/NEW/test/"
parse(PATH)
# Out:
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbwsjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 140316)
# ['Cbwsjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/brejson.json
# ['Cbwsjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbqsjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 146980)
# ['Cbwsjson.json', 'Cbqsjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbvljson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 162909)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bgcjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/btrjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/byxjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/birjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bgujson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbdvjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 174721)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbbqjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 161367)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/byujson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/beyjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbaejson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 218462)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bejjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbcejson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 169151)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbpyjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 156944)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bizjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bdcjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbtrjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 157670)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbgyjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 151789)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbgxjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 157339)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bgyjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bucjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bzrjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbcajson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 144817)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bpljson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbwvjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 166377)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bwfjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bhzjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbkzjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 161171)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bjxjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbdejson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 161597)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbaljson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 143781)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbfljson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 179532)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bhojson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bxrjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbgsjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 195073)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbnfjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 177806)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bwxjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bvhjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bwgjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbtvjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 142088)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbubjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 185695)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bnhjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bvgjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bvyjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bisjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bwrjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbqvjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 143271)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cboojson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 182525)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bdujson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbtsjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 149152)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbbajson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 178781)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bsbjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/btljson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/byajson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/borjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bdzjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bnejson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bsfjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bsljson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbnvjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 155394)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbygjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 159878)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bgnjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bvnjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bxsjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bdnjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bjyjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bigjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bfrjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbxsjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 180053)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bnkjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbbdjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 150310)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json', 'Cbbdjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbjejson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 163585)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json', 'Cbbdjson.json', 'Cbjejson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/benjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json', 'Cbbdjson.json', 'Cbjejson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bojjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json', 'Cbbdjson.json', 'Cbjejson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbopjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 167668)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json', 'Cbbdjson.json', 'Cbjejson.json', 'Cbopjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbqrjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 133820)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json', 'Cbbdjson.json', 'Cbjejson.json', 'Cbopjson.json', 'Cbqrjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbiijson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 136674)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json', 'Cbbdjson.json', 'Cbjejson.json', 'Cbopjson.json', 'Cbqrjson.json', 'Cbiijson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bpnjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json', 'Cbbdjson.json', 'Cbjejson.json', 'Cbopjson.json', 'Cbqrjson.json', 'Cbiijson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbfujson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 153203)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json', 'Cbbdjson.json', 'Cbjejson.json', 'Cbopjson.json', 'Cbqrjson.json', 'Cbiijson.json', 'Cbfujson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbwcjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 152470)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json', 'Cbbdjson.json', 'Cbjejson.json', 'Cbopjson.json', 'Cbqrjson.json', 'Cbiijson.json', 'Cbfujson.json', 'Cbwcjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbbvjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 167942)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json', 'Cbbdjson.json', 'Cbjejson.json', 'Cbopjson.json', 'Cbqrjson.json', 'Cbiijson.json', 'Cbfujson.json', 'Cbwcjson.json', 'Cbbvjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbhnjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 164562)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json', 'Cbbdjson.json', 'Cbjejson.json', 'Cbopjson.json', 'Cbqrjson.json', 'Cbiijson.json', 'Cbfujson.json', 'Cbwcjson.json', 'Cbbvjson.json', 'Cbhnjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbtljson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 163524)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json', 'Cbbdjson.json', 'Cbjejson.json', 'Cbopjson.json', 'Cbqrjson.json', 'Cbiijson.json', 'Cbfujson.json', 'Cbwcjson.json', 'Cbbvjson.json', 'Cbhnjson.json', 'Cbtljson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbhsjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 165425)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json', 'Cbbdjson.json', 'Cbjejson.json', 'Cbopjson.json', 'Cbqrjson.json', 'Cbiijson.json', 'Cbfujson.json', 'Cbwcjson.json', 'Cbbvjson.json', 'Cbhnjson.json', 'Cbtljson.json', 'Cbhsjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bkdjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json', 'Cbbdjson.json', 'Cbjejson.json', 'Cbopjson.json', 'Cbqrjson.json', 'Cbiijson.json', 'Cbfujson.json', 'Cbwcjson.json', 'Cbbvjson.json', 'Cbhnjson.json', 'Cbtljson.json', 'Cbhsjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbnsjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 150624)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json', 'Cbbdjson.json', 'Cbjejson.json', 'Cbopjson.json', 'Cbqrjson.json', 'Cbiijson.json', 'Cbfujson.json', 'Cbwcjson.json', 'Cbbvjson.json', 'Cbhnjson.json', 'Cbtljson.json', 'Cbhsjson.json', 'Cbnsjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bvdjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json', 'Cbbdjson.json', 'Cbjejson.json', 'Cbopjson.json', 'Cbqrjson.json', 'Cbiijson.json', 'Cbfujson.json', 'Cbwcjson.json', 'Cbbvjson.json', 'Cbhnjson.json', 'Cbtljson.json', 'Cbhsjson.json', 'Cbnsjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bakjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json', 'Cbbdjson.json', 'Cbjejson.json', 'Cbopjson.json', 'Cbqrjson.json', 'Cbiijson.json', 'Cbfujson.json', 'Cbwcjson.json', 'Cbbvjson.json', 'Cbhnjson.json', 'Cbtljson.json', 'Cbhsjson.json', 'Cbnsjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbsqjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 142186)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json', 'Cbbdjson.json', 'Cbjejson.json', 'Cbopjson.json', 'Cbqrjson.json', 'Cbiijson.json', 'Cbfujson.json', 'Cbwcjson.json', 'Cbbvjson.json', 'Cbhnjson.json', 'Cbtljson.json', 'Cbhsjson.json', 'Cbnsjson.json', 'Cbsqjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbibjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 163761)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json', 'Cbbdjson.json', 'Cbjejson.json', 'Cbopjson.json', 'Cbqrjson.json', 'Cbiijson.json', 'Cbfujson.json', 'Cbwcjson.json', 'Cbbvjson.json', 'Cbhnjson.json', 'Cbtljson.json', 'Cbhsjson.json', 'Cbnsjson.json', 'Cbsqjson.json', 'Cbibjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbufjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 145305)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json', 'Cbbdjson.json', 'Cbjejson.json', 'Cbopjson.json', 'Cbqrjson.json', 'Cbiijson.json', 'Cbfujson.json', 'Cbwcjson.json', 'Cbbvjson.json', 'Cbhnjson.json', 'Cbtljson.json', 'Cbhsjson.json', 'Cbnsjson.json', 'Cbsqjson.json', 'Cbibjson.json', 'Cbufjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbfwjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 154967)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json', 'Cbbdjson.json', 'Cbjejson.json', 'Cbopjson.json', 'Cbqrjson.json', 'Cbiijson.json', 'Cbfujson.json', 'Cbwcjson.json', 'Cbbvjson.json', 'Cbhnjson.json', 'Cbtljson.json', 'Cbhsjson.json', 'Cbnsjson.json', 'Cbsqjson.json', 'Cbibjson.json', 'Cbufjson.json', 'Cbfwjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbbujson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 203217)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json', 'Cbbdjson.json', 'Cbjejson.json', 'Cbopjson.json', 'Cbqrjson.json', 'Cbiijson.json', 'Cbfujson.json', 'Cbwcjson.json', 'Cbbvjson.json', 'Cbhnjson.json', 'Cbtljson.json', 'Cbhsjson.json', 'Cbnsjson.json', 'Cbsqjson.json', 'Cbibjson.json', 'Cbufjson.json', 'Cbfwjson.json', 'Cbbujson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbfvjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 195885)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json', 'Cbbdjson.json', 'Cbjejson.json', 'Cbopjson.json', 'Cbqrjson.json', 'Cbiijson.json', 'Cbfujson.json', 'Cbwcjson.json', 'Cbbvjson.json', 'Cbhnjson.json', 'Cbtljson.json', 'Cbhsjson.json', 'Cbnsjson.json', 'Cbsqjson.json', 'Cbibjson.json', 'Cbufjson.json', 'Cbfwjson.json', 'Cbbujson.json', 'Cbfvjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/buzjson.json
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json', 'Cbbdjson.json', 'Cbjejson.json', 'Cbopjson.json', 'Cbqrjson.json', 'Cbiijson.json', 'Cbfujson.json', 'Cbwcjson.json', 'Cbbvjson.json', 'Cbhnjson.json', 'Cbtljson.json', 'Cbhsjson.json', 'Cbnsjson.json', 'Cbsqjson.json', 'Cbibjson.json', 'Cbufjson.json', 'Cbfwjson.json', 'Cbbujson.json', 'Cbfvjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbtqjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 196823)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json', 'Cbbdjson.json', 'Cbjejson.json', 'Cbopjson.json', 'Cbqrjson.json', 'Cbiijson.json', 'Cbfujson.json', 'Cbwcjson.json', 'Cbbvjson.json', 'Cbhnjson.json', 'Cbtljson.json', 'Cbhsjson.json', 'Cbnsjson.json', 'Cbsqjson.json', 'Cbibjson.json', 'Cbufjson.json', 'Cbfwjson.json', 'Cbbujson.json', 'Cbfvjson.json', 'Cbtqjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbxbjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 180053)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json', 'Cbbdjson.json', 'Cbjejson.json', 'Cbopjson.json', 'Cbqrjson.json', 'Cbiijson.json', 'Cbfujson.json', 'Cbwcjson.json', 'Cbbvjson.json', 'Cbhnjson.json', 'Cbtljson.json', 'Cbhsjson.json', 'Cbnsjson.json', 'Cbsqjson.json', 'Cbibjson.json', 'Cbufjson.json', 'Cbfwjson.json', 'Cbbujson.json', 'Cbfvjson.json', 'Cbtqjson.json', 'Cbxbjson.json'] 0
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/bqfjson.json
# ...
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbvbjson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 152183)
# ['Cbwsjson.json', 'Cbqsjson.json', 'Cbvljson.json', 'Cbdvjson.json', 'Cbbqjson.json', 'Cbaejson.json', 'Cbcejson.json', 'Cbpyjson.json', 'Cbtrjson.json', 'Cbgyjson.json', 'Cbgxjson.json', 'Cbcajson.json', 'Cbwvjson.json', 'Cbkzjson.json', 'Cbdejson.json', 'Cbaljson.json', 'Cbfljson.json', 'Cbgsjson.json', 'Cbnfjson.json', 'Cbtvjson.json', 'Cbubjson.json', 'Cbqvjson.json', 'Cboojson.json', 'Cbtsjson.json', 'Cbbajson.json', 'Cbnvjson.json', 'Cbygjson.json', 'Cbxsjson.json', 'Cbbdjson.json', 'Cbjejson.json', 'Cbopjson.json', 'Cbqrjson.json', 'Cbiijson.json', 'Cbfujson.json', 'Cbwcjson.json', 'Cbbvjson.json', 'Cbhnjson.json', 'Cbtljson.json', 'Cbhsjson.json', 'Cbnsjson.json', 'Cbsqjson.json', 'Cbibjson.json', 'Cbufjson.json', 'Cbfwjson.json', 'Cbbujson.json', 'Cbfvjson.json', 'Cbtqjson.json', 'Cbxbjson.json', 'Cbnbjson.json', 'Cbsfjson.json', 'Cbdojson.json', 'Cbcljson.json', 'Cbhijson.json', 'Cbuijson.json', 'Cbzjjson.json', 'Cbiajson.json', 'Cbuojson.json', 'Cbyjjson.json', 'Cbudjson.json', 'Cbgwjson.json', 'Cbqgjson.json', 'Cbiyjson.json', 'Cbrljson.json', 'Cbssjson.json', 'Cbnujson.json', 'Cbdzjson.json', 'Cbiejson.json', 
 'Cbprjson.json', 'Cbojjson.json', 'Cbvvjson.json', 'Cbtajson.json', 'Cbyvjson.json', 'Cbacjson.json', 'Cbjsjson.json', 'Cbxxjson.json', 'Cbnjjson.json', 'Cbdwjson.json', 'Cbeujson.json', 'Cbfkjson.json', 'Cboqjson.json', 'Cbbkjson.json', 'Cbkujson.json', 'Cboejson.json', 'Cbcujson.json', 'Cbysjson.json', 'Cbihjson.json', 'Cbppjson.json', 'Cbqhjson.json', 'Cbayjson.json', 'Cbvtjson.json', 'Cbjnjson.json', 'Cbtnjson.json', 'Cbiqjson.json', 'Cbvxjson.json', 'Cbckjson.json', 'Cbqxjson.json', 'Cbuyjson.json', 'Cbcijson.json', 'Cbgljson.json', 'Cbypjson.json', 'Cbhvjson.json', 'Cbwjjson.json', 'Cbtpjson.json', 'Cbdujson.json', 'Cblojson.json', 'Cbdbjson.json', 'Cbydjson.json', 'Cbspjson.json', 'Cbqujson.json', 'Cbbljson.json', 'Cbwhjson.json', 'Cbtgjson.json', 'Cbzqjson.json', 'Cbwfjson.json', 'Cbzajson.json', 'Cbrojson.json', 'Cbdijson.json', 'Cbbnjson.json', 'Cbvejson.json', 'Cbzkjson.json', 'Cblejson.json', 'Cbvpjson.json', 'Cbqqjson.json', 'Cbwpjson.json', 'Cbzcjson.json', 'Cbb ...
# /home/jack/Desktop/ChatterBot-Stuff/NEW/test/Cbqljson.json
# JSON object issue:  Expecting ',' delimiter or ']': line 5000 column 1 (char 178443)
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
invalid_json_files = []
read_json_files = []
def parse():
    for files in os.listdir(os.getcwd()):
        print(files)
        with open(files) as json_file:
            try:
                simplejson.load(json_file)
                read_json_files.append(files)
            except ValueError as e:
                print ("JSON object issue: %s") % e
                invalid_json_files.append(files)
    print (invalid_json_files, len(read_json_files))

# %%
import json

jsonData="/home/jack/Desktop/ChatterBot-Stuff/superchatbackup/statements.json"
json.loads(jsonData)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-135-7fbadc30ac56> in <module>
#       2
#       3 jsonData="/home/jack/Desktop/ChatterBot-Stuff/superchatbackup/statements.json"
# ----> 4 json.loads(jsonData)
#
# ~/miniconda3/envs/deep/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~/miniconda3/envs/deep/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/miniconda3/envs/deep/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
import json
import os  
import string
import io
from ruamel.yaml import YAML
from ruamel.yaml.reader import Reader

yaml = YAML(typ='safe')


def strip_invalid(s):
    res = ''
    for x in s:
        if Reader.NON_PRINTABLE.match(x):
            # res += '\\x{:x}'.format(ord(x))
            continue
        res += x
    return res

def convert(filename) :
    count = 0
    #ALL = [] 
    
    #f = io.open(filename, mode="r", encode("latin_1"),decode("utf_8")).readlines()
    f = io.open(filename, mode="r", encoding="utf-8").readlines()
    #f = open(filename, "r").readlines()
    for line in f:
        line = line.encode('utf8').decode('latin1')
        line = line.replace("\n","")
        line =line.replace("\"","'")
        line=line.replace("\\","")
        line=line.replace("{","")
        line=line.replace("}","")
        line = strip_invalid(line)
        count=count+1
        newline =[]
        txt = "[\""
        if(count % 2 != 0):
            newline.append(""+line +"")
            txt2 = txt+line
        if(count % 2 == 0):
            newline.append(""+line +"")
            txt3 = txt2 +"\",\n\""+ line +"\"],\n"
            if count<5000:datain.write(txt3)
    return #print("--\n",ALL)
cnt=0
SUB = ['a','b','c','d','e','f','g','h','i','j','k','l','n','o','p','q','r','s','t','u','v','w','x','y','z']
for sub in SUB:
    FS = ['a','b','c','d','e','f','g','h','i','j','k','l','n','o','p','q','r','s','t','u','v','w','x','y','z']
    for L in FS:
        #def savjson(data):
        datain = open("test/b"+sub+L+"json.json","w")
        datain.write("{\n \"conversations\": \n[\n")
        convert("/home/jack/Desktop/PAV/opensubtitles/raw/lines/lines-a"+sub+L+"") 
        datain.write("]}")
        datain.close() 
        file = "test/a"+sub+L+"json.json"
        #print(file)
    
    
        data = open(file).readlines()
        newfile = "test/C"+os.path.basename(file)
        clean = open(newfile, "w")
        count = 0
        for line in data:
            count=count+1
            if count<4999:
                #print(line)
                clean.write(line)
            if count>4998:
                line = line.replace("],","]")
                clean.write(line)
                #print(line)

    clean.close()

# %%
for filein in filelist:
    count = count+1
    if count<20:
        trainer.train(filein)

filelist = []
count = 0
from glob import glob
for f_name in glob('test/b*.json'):
     filelist.append(f_name)
for filein in filelist:
    count = count+1
    if count<20:
        print(filein)
# Out:
# test/brejson.json
# test/bgcjson.json
# test/btrjson.json
# test/byxjson.json
# test/birjson.json
# test/bgujson.json
# test/byujson.json
# test/beyjson.json
# test/bejjson.json
# test/bizjson.json
# test/bdcjson.json
# test/bgyjson.json
# test/bucjson.json
# test/bzrjson.json
# test/bpljson.json
# test/bwfjson.json
# test/bhzjson.json
# test/bjxjson.json
# test/bhojson.json

# %%
filelist = []
count = 0
from glob import glob
for f_name in glob('test/b*.json'):
     filelist.append(f_name)
for filein in filelist:
    count = count+1
    if count<20:
        print(filein)
# Out:
# test/brejson.json
# test/bgcjson.json
# test/btrjson.json
# test/byxjson.json
# test/birjson.json
# test/bgujson.json
# test/byujson.json
# test/beyjson.json
# test/bejjson.json
# test/bizjson.json
# test/bdcjson.json
# test/bgyjson.json
# test/bucjson.json
# test/bzrjson.json
# test/bpljson.json
# test/bwfjson.json
# test/bhzjson.json
# test/bjxjson.json
# test/bhojson.json

# %%
# %load Botman
#!/home/jack/miniconda3/envs/deep/bin/python
from chatterbot import ChatBot
from chatterbot.trainers import ChatterBotCorpusTrainer
import logging
import bson

# Uncomment the following line to enable verbose logging
# logging.basicConfig(level=logging.INFO)

# Create a new ChatBot instance
Botman = ChatBot('Botman',
    storage_adapter='chatterbot.storage.MongoDatabaseAdapter',
    logic_adapters=['chatterbot.logic.BestMatch'],
    filters=['chatterbot.filters.RepetitiveResponseFilter'],
    input_adapter='chatterbot.input.TerminalAdapter',
    output_adapter='chatterbot.output.TerminalAdapter',
    database_uri='mongodb://localhost:27017/super-chatbot'
)
trainer = ChatterBotCorpusTrainer(Botman)

"""       
filelist = []
count = 0
from glob import glob
for f_name in glob('test/b*.json'):
     filelist.append(f_name)
for filein in filelist:
    count = count+1
    if count<20:
        trainer.train(filein)         
"""        
        
#trainer.train("chatterbot.corpus.english")
#trainer.train("./father.corpus.json")
#trainer.train("./export2.json")
#from glob import glob
#for f_name in glob('test/b*.json'):
#    try:
#        trainer.train(f_name)
#        filelist.append(f_name)
#    except Exception:
#        pass
    
    
    
#Botman.trainer.export_for_training('GIGANTIC.json')


print('Type something to begin...')

while True:
    try:
        user_input = input()
        if user_input=="quit":
            break
        bot_response = Botman.get_response(user_input)

        print(bot_response)

    # Press ctrl-c or ctrl-d on the keyboard to exit
    except (KeyboardInterrupt, EOFError, SystemExit):
        break
#chatbot.get_response("Hello, how are you today?")
# Out:
# Training brejson.json: [####################] 100%
# Training bgcjson.json: [####################] 100%
# Training btrjson.json: [####################] 100%
# Training byxjson.json: [####################] 100%
# Training birjson.json: [####################] 100%
# Training bgujson.json: [####################] 100%
# Training byujson.json: [####################] 100%
# Training beyjson.json: [####################] 100%
# Training bejjson.json: [####################] 100%
# Training bizjson.json: [####################] 100%
# Training bdcjson.json: [####################] 100%
# Training bgyjson.json: [####################] 100%
# Training bucjson.json: [####################] 100%
# Training bzrjson.json: [####################] 100%
# Training bpljson.json: [####################] 100%
# ---------------------------------------------------------------------------
# ScannerError                              Traceback (most recent call last)
# <ipython-input-87-9e5d5b5b64b8> in <module>
#      29     count = count+1
#      30     if count<20:
# ---> 31         trainer.train(filein)
#      32
#      33
#
# ~/miniconda3/envs/deep/lib/python3.7/site-packages/ChatterBot-1.1.0a7-py3.7.egg/chatterbot/trainers.py in train(self, *corpus_paths)
#     133             data_file_paths.extend(list_corpus_files(corpus_path))
#     134
# --> 135         for corpus, categories, file_path in load_corpus(*data_file_paths):
#     136
#     137             statements_to_create = []
#
# ~/miniconda3/envs/deep/lib/python3.7/site-packages/ChatterBot-1.1.0a7-py3.7.egg/chatterbot/corpus.py in load_corpus(*data_file_paths)
#      82     for file_path in data_file_paths:
#      83         corpus = []
# ---> 84         corpus_data = read_corpus(file_path)
#      85
#      86         conversations = corpus_data.get('conversations', [])
#
# ~/miniconda3/envs/deep/lib/python3.7/site-packages/ChatterBot-1.1.0a7-py3.7.egg/chatterbot/corpus.py in read_corpus(file_name)
#      57
#      58     with io.open(file_name, encoding='utf-8') as data_file:
# ---> 59         return yaml.safe_load(data_file)
#      60
#      61
#
# ~/miniconda3/envs/deep/lib/python3.7/site-packages/yaml/__init__.py in safe_load(stream)
#      92     Resolve only basic YAML tags.
#      93     """
# ---> 94     return load(stream, SafeLoader)
#      95
#      96 def safe_load_all(stream):
#
# ~/miniconda3/envs/deep/lib/python3.7/site-packages/yaml/__init__.py in load(stream, Loader)
#      70     loader = Loader(stream)
#      71     try:
# ---> 72         return loader.get_single_data()
#      73     finally:
#      74         loader.dispose()
#
# ~/miniconda3/envs/deep/lib/python3.7/site-packages/yaml/constructor.py in get_single_data(self)
#      33     def get_single_data(self):
#      34         # Ensure that the stream contains a single document and construct it.
# ---> 35         node = self.get_single_node()
#      36         if node is not None:
#      37             return self.construct_document(node)
#
# ~/miniconda3/envs/deep/lib/python3.7/site-packages/yaml/composer.py in get_single_node(self)
#      34         document = None
#      35         if not self.check_event(StreamEndEvent):
# ---> 36             document = self.compose_document()
#      37
#      38         # Ensure that the stream contains no more documents.
#
# ~/miniconda3/envs/deep/lib/python3.7/site-packages/yaml/composer.py in compose_document(self)
#      53
#      54         # Compose the root node.
# ---> 55         node = self.compose_node(None, None)
#      56
#      57         # Drop the DOCUMENT-END event.
#
# ~/miniconda3/envs/deep/lib/python3.7/site-packages/yaml/composer.py in compose_node(self, parent, index)
#      82             node = self.compose_sequence_node(anchor)
#      83         elif self.check_event(MappingStartEvent):
# ---> 84             node = self.compose_mapping_node(anchor)
#      85         self.ascend_resolver()
#      86         return node
#
# ~/miniconda3/envs/deep/lib/python3.7/site-packages/yaml/composer.py in compose_mapping_node(self, anchor)
#     131             #    raise ComposerError("while composing a mapping", start_event.start_mark,
#     132             #            "found duplicate key", key_event.start_mark)
# --> 133             item_value = self.compose_node(node, item_key)
#     134             #node.value[item_key] = item_value
#     135             node.value.append((item_key, item_value))
#
# ~/miniconda3/envs/deep/lib/python3.7/site-packages/yaml/composer.py in compose_node(self, parent, index)
#      80             node = self.compose_scalar_node(anchor)
#      81         elif self.check_event(SequenceStartEvent):
# ---> 82             node = self.compose_sequence_node(anchor)
#      83         elif self.check_event(MappingStartEvent):
#      84             node = self.compose_mapping_node(anchor)
#
# ~/miniconda3/envs/deep/lib/python3.7/site-packages/yaml/composer.py in compose_sequence_node(self, anchor)
#     108             self.anchors[anchor] = node
#     109         index = 0
# --> 110         while not self.check_event(SequenceEndEvent):
#     111             node.value.append(self.compose_node(node, index))
#     112             index += 1
#
# ~/miniconda3/envs/deep/lib/python3.7/site-packages/yaml/parser.py in check_event(self, *choices)
#      96         if self.current_event is None:
#      97             if self.state:
# ---> 98                 self.current_event = self.state()
#      99         if self.current_event is not None:
#     100             if not choices:
#
# ~/miniconda3/envs/deep/lib/python3.7/site-packages/yaml/parser.py in parse_flow_sequence_entry(self, first)
#     484                             "expected ',' or ']', but got %r" % token.id, token.start_mark)
#     485
# --> 486             if self.check_token(KeyToken):
#     487                 token = self.peek_token()
#     488                 event = MappingStartEvent(None, None, True,
#
# ~/miniconda3/envs/deep/lib/python3.7/site-packages/yaml/scanner.py in check_token(self, *choices)
#     114         # Check if the next token is one of the given types.
#     115         while self.need_more_tokens():
# --> 116             self.fetch_more_tokens()
#     117         if self.tokens:
#     118             if not choices:
#
# ~/miniconda3/envs/deep/lib/python3.7/site-packages/yaml/scanner.py in fetch_more_tokens(self)
#     246         # Is it a double quoted scalar?
#     247         if ch == '\"':
# --> 248             return self.fetch_double()
#     249
#     250         # It must be a plain scalar then.
#
# ~/miniconda3/envs/deep/lib/python3.7/site-packages/yaml/scanner.py in fetch_double(self)
#     650
#     651     def fetch_double(self):
# --> 652         self.fetch_flow_scalar(style='"')
#     653
#     654     def fetch_flow_scalar(self, style):
#
# ~/miniconda3/envs/deep/lib/python3.7/site-packages/yaml/scanner.py in fetch_flow_scalar(self, style)
#     661
#     662         # Scan and add SCALAR.
# --> 663         self.tokens.append(self.scan_flow_scalar(style))
#     664
#     665     def fetch_plain(self):
#
# ~/miniconda3/envs/deep/lib/python3.7/site-packages/yaml/scanner.py in scan_flow_scalar(self, style)
#    1144         quote = self.peek()
#    1145         self.forward()
# -> 1146         chunks.extend(self.scan_flow_scalar_non_spaces(double, start_mark))
#    1147         while self.peek() != quote:
#    1148             chunks.extend(self.scan_flow_scalar_spaces(double, start_mark))
#
# ~/miniconda3/envs/deep/lib/python3.7/site-packages/yaml/scanner.py in scan_flow_scalar_non_spaces(self, double, start_mark)
#    1218                 else:
#    1219                     raise ScannerError("while scanning a double-quoted scalar", start_mark,
# -> 1220                             "found unknown escape character %r" % ch, self.get_mark())
#    1221             else:
#    1222                 return chunks
#
# ScannerError: while scanning a double-quoted scalar
#   in "test/bwfjson.json", line 4165, column 1
# found unknown escape character 'c'
#   in "test/bwfjson.json", line 4165, column 9

# %%
f = io.open("/home/jack/Desktop/PAV/opensubtitles/raw/lines/lines-aaa", mode="r", encoding="utf-8")

# %%
# !mkdir superchatbackup

# %%
# %%writefile backupsuper.py
from os.path import join
import pymongo
from bson.json_util import dumps

def backup_db(backup_db_dir):
    client = pymongo.MongoClient(host="mongodb://localhost", port=27017)
    database = client["super-chatbot"]
    collections = database.list_collection_names()

    for i, collection_name in enumerate(collections):
        col = getattr(database,collections[i])
        collection = col.find()
        jsonpath = collection_name + ".json"
        jsonpath = join(backup_db_dir, jsonpath)
        with open(jsonpath, 'wb') as jsonfile:
            jsonfile.write(dumps(collection).encode())


backup_db('./superchatbackup')
# Out:
# Overwriting backupsuper.py

# %%
import json
import io
import string
datain = open("test/test.json","w")    
datain.write("{\n \"conversations\": \n[\n")
def convert() :
    count = 0
    #ALL = []
    #f = open("/home/jack/Desktop/PAV/opensubtitles/raw/lines/lines-aaa", "r").readlines()
    f = io.open("/home/jack/Desktop/PAV/opensubtitles/raw/lines/lines-aaa", mode="r", encoding="utf-8").readlines()
    #f= filter(lambda x: x in string.printable, f)
    for line in f:
        line = line.replace("\n","")
        line =line.replace("\"","'")
        
        count=count+1
        newline =[]
        txt = "[\""
        if(count % 2 != 0):
            newline.append(""+line +"")
            txt2 = txt+line
        if(count % 2 == 0):
            newline.append(""+line +"")
            txt3 = txt2 +"\",\n\""+ line +"\"],\n"
            if count<5000:datain.write(txt3)
    return #print("--\n",ALL)

convert() 
datain.write("]}")
datain.close()

# %%
import json
import string

filtered_string = filter(lambda x: x in string.printable, myStr)

L = input("Which file: ")
print(L)
#def savjson(data):
datain = open("aa"+L+"json.json","w")
    
datain.write("{\n \"conversations\": \n[\n")
def convert() :
    count = 0
    #ALL = []
    f = open("/home/jack/Desktop/PAV/opensubtitles/raw/lines/lines-aa"+L+"", "r").readlines()
    for line in f:
        line = line.replace("\n","")
        Line =line.replace("âª","") 
        line =line.replace("\"","'")
        
        count=count+1
        newline =[]
        txt = "[\""
        if(count % 2 != 0):
            newline.append(""+line +"")
            txt2 = txt+line
        if(count % 2 == 0):
            newline.append(""+line +"")
            txt3 = txt2 +"\",\n\""+ line +"\"],\n"
            if count<5000:datain.write(txt3)
    return #print("--\n",ALL)

convert() 
datain.write("]}")
datain.close() 
file = "aa"+L+"json.json"
print(file)
# Out:
# Which file: z
# z
# aazjson.json

# %%
from glob import glob

for f_name in glob('test/C*.json'):
    print(f_name)
# Out:
# test/Cbwsjson.json
# test/Cbqsjson.json
# test/Cbvljson.json
# test/Cbdvjson.json
# test/Cbbqjson.json
# test/Cbaejson.json
# test/Cbcejson.json
# test/Cbpyjson.json
# test/Cbtrjson.json
# test/Cbgyjson.json
# test/Cbgxjson.json
# test/Cbcajson.json
# test/Cbwvjson.json
# test/Cbkzjson.json
# test/Cbdejson.json
# test/Cbaljson.json
# test/Cbfljson.json
# test/Cbgsjson.json
# test/Cbnfjson.json
# test/Cbtvjson.json
# test/Cbubjson.json
# test/Cbqvjson.json
# test/Cboojson.json
# test/Cbtsjson.json
# test/Cbbajson.json
# test/Cbnvjson.json
# test/Cbygjson.json
# test/Cbxsjson.json
# test/Cbbdjson.json
# test/Cbjejson.json
# test/Cbopjson.json
# test/Cbqrjson.json
# test/Cbiijson.json
# test/Cbfujson.json
# test/Cbwcjson.json
# test/Cbbvjson.json
# test/Cbhnjson.json
# test/Cbtljson.json
# test/Cbhsjson.json
# test/Cbnsjson.json
# test/Cbsqjson.json
# test/Cbjajson.json
# test/Cbvijson.json
# test/Cbfejson.json
# test/Cbgjjson.json
# test/Cbzvjson.json
# test/Cbdsjson.json
# test/Cbwtjson.json
# test/Cbxgjson.json
# test/Cbdqjson.json
# test/Cbcnjson.json
# test/Cbecjson.json
# test/Cbrsjson.json
# test/Cbozjson.json
# test/Cbaqjson.json
# test/Cbhbjson.json
# test/Cbstjson.json
# test/Cbwqjson.json
# test/Cbcdjson.json
# test/Cbxqjson.json
# test/Cbrtjson.json
# test/Cbbzjson.json
# test/Cbizjson.json
# test/Cbcjjson.json
# test/Cbpejson.json
# test/Cbszjson.json
# test/Cbrkjson.json
# test/Cbyqjson.json
# test/Cbohjson.json
# test/Cbpljson.json
# test/Cbxljson.json
# test/Cbtcjson.json
# test/Cbuqjson.json
# test/Cbefjson.json
# test/Cbjljson.json
# test/Cbbwjson.json
# test/Cbjxjson.json
# test/Cbjdjson.json
# test/Cbgvjson.json
# test/Cbftjson.json
# test/Cbvsjson.json
# test/Cbvcjson.json
# test/Cbvrjson.json
# test/Cbcgjson.json
# test/Cbidjson.json
# test/Cbjwjson.json
# test/Cbfxjson.json
# test/Cbjgjson.json
# test/Cbvajson.json
# test/Cbinjson.json
# test/Cbltjson.json
# test/Cbzfjson.json
# test/Cbwljson.json
# test/Cbtbjson.json
# test/Cbcojson.json
# test/Cbrujson.json
# test/Cbrxjson.json
# test/Cbhejson.json
# test/Cbxkjson.json
# test/Cbkajson.json
# test/Cbgqjson.json
# test/Cbesjson.json
# test/Cbybjson.json
# test/Cbrdjson.json
# test/Cblcjson.json
# test/Cbitjson.json
# test/Cbzejson.json
# test/Cbadjson.json
# test/Cbowjson.json
# test/Cbpsjson.json
# test/Cbdpjson.json
# test/Cbkojson.json
# test/Cbjyjson.json
# test/Cbiojson.json
# test/Cbrzjson.json
# test/Cbhyjson.json
# test/Cbivjson.json
# test/Cbkcjson.json
# test/Cbwujson.json
# test/Cbcyjson.json
# test/Cbicjson.json
# test/Cbrijson.json
# test/Cbuzjson.json
# test/Cbbrjson.json
# test/Cbixjson.json
# test/Cbhxjson.json
# test/Cbjtjson.json
# test/Cbsrjson.json
# test/Cbldjson.json
# test/Cbyzjson.json

# %%
data = open(file).readlines()
clean = open("C"+file, "w")
count = 0
for line in data:
    count=count+1
    if count<4999:
        #print(line)
        clean.write(line)
    if count>4998:
        line = line.replace("],","]")
        clean.write(line)
        #print(line)
        
clean.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-50-ed5b070a7d97> in <module>
#       1 data = open(file).readlines()
# ----> 2 clean = open("C"+file, "w")
#       3 count = 0
#       4 for line in data:
#       5     count=count+1
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Ctest/bzzjson.json'

# %%
# !ls C*
# Out:
# Caazjson.json  CorpaMaker-Copy1.ipynb  CorpaMaker.ipynb  CorpusCreator.ipynb
#
# ChatterBot:
# build		      dist	__ini__py    requirements.txt  tests
# chatterbot	      docs	LICENSE      runtests.py       tests_django
# ChatterBot.egg-info   examples	MANIFEST.in  setup.cfg	       tox.ini
# dev-requirements.txt  graphics	README.md    setup.py
#
# Corpus:
# test.corpus.json
