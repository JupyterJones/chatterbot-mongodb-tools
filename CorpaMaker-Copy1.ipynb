# %% [markdown]
# This Notebook will generate copra in the same format as used by ChatBot. The entire *.corpus.json file may be generated. <br/>
# First run the Title_Maker. <br/>
# ### ----------------warning ------------
# ###### RUN Title_Maker once with the same filename <br/>
# ##### A second writing, with the same filename,   will over write any and all files generated by ' Corpra_Writer '<br />
# * Beware using this file, if re-using the same filename and you have started the ' Copra_Maker ',  it can be overwritten.
# ### --------------end warning ----------
# The raw_input box will write the file and the heading of the filename entered. The *  part of *.corpus.json. The base file will be generated. <br/>
#
# Example if you enter ' my-personal ' in the input box, it will generate a ' my_personal.corpus.json ' filename.<br/>
# Then run the Copra_Maker and add conversation as you wish.<br/>

# %%
# !ls chatterbot-corpus/chatterbot_corpus/data/english
# Out:
# ai.corpus.json		   greetings.corpus.json   my.corpus.json
# botprofile.corpus.json	   history.corpus.json	   politics.corpus.json
# computers.corpus.json	   humor.corpus.json	   psychology.corpus.json
# conversations.corpus.json  literature.corpus.json  science.corpus.json
# drugs.corpus.json	   math_words.json	   sports.corpus.json
# emotion.corpus.json	   money.corpus.json	   swear_words.csv
# food.corpus.json	   movies.corpus.json	   trivia.corpus.json
# gossip.corpus.json	   mycorpa.corpus.json

# %%
# Title_Maker 
def coptitle(coptit):
    copt = open("chatterbot-corpus/chatterbot_corpus/data/english/"+ coptit + ".corpus.json","w")
    copbrac ="{"
    copsp = "\n    \""
    copclo = "\": ["
    copt.write(copbrac+copsp+coptit+copclo)
    copt.close()
coptit = raw_input('title')
coptitle(coptit)
# Out:
# titlechitchat

# %%
# !rm chatterbot-corpus/chatterbot_corpus/data/english/  chitcht.corpus.json
# Out:
# rm: cannot remove 'chatterbot-corpus/chatterbot_corpus/data/english/': Is a directory
# rm: cannot remove 'chitcht.corpus.json': No such file or directory

# %%
# !ls chatterbot-corpus/chatterbot_corpus/data/english/
# Out:
# ai.corpus.json		   food.corpus.json	   mycorpa.corpus.json
# botprofile.corpus.json	   gossip.corpus.json	   my.corpus.json
# chitchat.corpus.json	   greetings.corpus.json   politics.corpus.json
#   chitcht.corpus.json	   history.corpus.json	   psychology.corpus.json
# computers.corpus.json	   humor.corpus.json	   science.corpus.json
# conversations.corpus.json  literature.corpus.json  sports.corpus.json
# coptit+.corpus.json	   math_words.json	   swear_words.csv
# drugs.corpus.json	   money.corpus.json	   trivia.corpus.json
# emotion.corpus.json	   movies.corpus.json

# %%
# !ls chatterbot-corpus/chatterbot_corpus/data/english/coptit+.corpus.json
# Out:
# chatterbot-corpus/chatterbot_corpus/data/english/coptit+.corpus.json

# %%
# %load chatterbot-corpus/chatterbot_corpus/data/english/chitchat.corpus.json
{
    "chitchat": [
        [
            "Hey, Dude, What you want ?"            
            "I want to know why you call me Dude ?"
        ],

# %%
# Copra_Maker
# Fillin the name of the file you just created
speak = raw_input('speak')
respond = raw_input('respond')
space = "            \""
txtstart = "        ["
txtspace = "            "
txtend = "        ],"

def copraIn():

   cop = open("chatterbot-corpus/chatterbot_corpus/data/english/chitchat.corpus.json","a")
   #cop.write("\n"+ txspace + "\""+txtstart + speak + "\"\n" + txspace + "\""+respond+"\"" + "\n" + txtend)
   cop.write("\n"+txtstart+"\n"+space+speak+"\""+txtspace+"\n"+space+respond+"\"\n"+txtend)
   cop.close()


copraIn()
# Out:
# speakHey, Dude, What you want ?
# respondI want to know why you call me Dude ?

# %%
# Train based on the english corpus
chatbot.train("chatterbot.corpus.english")

# Train based on english greetings corpus
chatbot.train("chatterbot.corpus.english.greetings")

# Train based on the english conversations corpus
chatbot.train("chatterbot.corpus.english.conversations")

# %%
from chatterbot import ChatBot

chatbot = ChatBot(
    'MonkMonk',
    trainer='chatterbot.trainers.ChatterBotCorpusTrainer'
)

# Train based on the english corpus
#chatbot.train("chatterbot.corpus.english")
chatbot.train("chatterbot.corpus.english")
# Get a response to an input statement
while True:
    try:
        bot_input = bot.get_response(None)

    # Press ctrl-c or ctrl-d on the keyboard to exit
    except (KeyboardInterrupt, EOFError, SystemExit):
        break
# Out:
# chatterbot/storage/jsonfile.py:26: UnsuitableForProductionWarning: The JsonFileStorageAdapter is not recommended for production environments.
#   self.UnsuitableForProductionWarning
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-29-f7f6c72cb88f> in <module>()
#       8 # Train based on the english corpus
#       9 #chatbot.train("chatterbot.corpus.english")
# ---> 10 chatbot.train("chatterbot.corpus.english.chitchat")
#      11 # Get a response to an input statement
#      12 while True:
#
# /home/jack/Desktop/ChatterBot/chatterbot/trainers.pyc in train(self, *corpora)
#     112
#     113         for corpus in corpora:
# --> 114             corpus_data = self.corpus.load_corpus(corpus)
#     115             for data in corpus_data:
#     116                 for pair in data:
#
# /home/jack/anaconda2/lib/python2.7/site-packages/chatterbot_corpus/corpus.pyc in load_corpus(self, dotted_path)
#      69
#      70         for file_path in data_file_paths:
# ---> 71             corpus = self.read_corpus(file_path)
#      72
#      73             for key in list(corpus.keys()):
#
# /home/jack/anaconda2/lib/python2.7/site-packages/chatterbot_corpus/corpus.pyc in read_corpus(self, file_name)
#      37         import io
#      38
# ---> 39         with io.open(file_name, encoding='utf-8') as data_file:
#      40             data = json.load(data_file)
#      41         return data
#
# IOError: [Errno 2] No such file or directory: '/home/jack/anaconda2/lib/python2.7/site-packages/chatterbot_corpus/data/english/chitchat'

# %% [markdown]
# # Title Maker
# def coptitle(coptit):
#     copt = open(coptit+".corpus.json","w")
#     copbrac ="{"
#     copsp = "\n    \""
#     copclo = "\": ["
#     copt.write(copbrac+copsp+coptit+copclo)
#     copt.close()
# coptit = raw_input('title')
# coptitle(coptit)

# %% [markdown]
# ## GOOD CODE - Don't Touch
#
# speak = raw_input('speak')
# respond = raw_input('respond')
# space = "            \""
# txtstart = "        ["
# txtspace = "            "
# txtend = "        ],"
#
# def copraIn():
#
#    cop = open("test.corpus.json","a")
#    #cop.write("\n"+ txspace + "\""+txtstart + speak + "\"\n" + txspace + "\""+respond+"\"" + "\n" + txtend)
#    cop.write("\n"+txtstart+"\n"+space+speak+"\""+txtspace+"\n"+space+respond+"\"\n"+txtend)
#    cop.close()
#
#
# copraIn()

# %%
# %load chatterbot-corpus/chatterbot_corpus/corpus.py
import os


class Corpus(object):

    def __init__(self):
        current_directory = os.path.dirname(os.path.abspath(__file__))
        self.data_directory = os.path.join(current_directory, 'data')

    def get_file_path(self, dotted_path, extension='json'):
        """
        Reads a dotted file path and returns the file path.
        """

        # If the operating system's file path seperator character is in the string
        if os.sep in dotted_path or '/' in dotted_path:
            # Assume the path is a valid file path
            return dotted_path

        parts = dotted_path.split('.')
        if parts[0] == 'chatterbot':
            parts.pop(0)
            parts[0] = self.data_directory

        corpus_path = os.path.join(*parts)

        if os.path.exists(corpus_path + '.{}'.format(extension)):
            corpus_path += '.{}'.format(extension)

        return corpus_path

    def read_corpus(self, file_name):
        """
        Read and return the data from a corpus json file.
        """
        import json
        import io

        with io.open(file_name, encoding='utf-8') as data_file:
            data = json.load(data_file)
        return data

    def list_corpus_files(self, dotted_path):
        """
        Return a list of file paths to each data file in
        the specified corpus.
        """
        corpus_path = self.get_file_path(dotted_path, extension='corpus.json')
        paths = []

        if os.path.isdir(corpus_path):
            for dirname, dirnames, filenames in os.walk(corpus_path):
                for datafile in filenames:
                    if datafile.endswith('corpus.json'):
                        paths.append(os.path.join(dirname, datafile))
        else:
            paths.append(corpus_path)

        paths.sort()
        return paths

    def load_corpus(self, dotted_path):
        """
        Return the data contained within a specified corpus.
        """
        data_file_paths = self.list_corpus_files(dotted_path)

        corpora = []

        for file_path in data_file_paths:
            corpus = self.read_corpus(file_path)

            for key in list(corpus.keys()):
                corpora.append(corpus[key])

        return corpora
